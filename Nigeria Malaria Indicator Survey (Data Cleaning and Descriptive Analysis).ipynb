# %% [markdown]
# # NIGERIA MALARIA DATA CLEANING AND DESCRIPTIVE ANALYSIS

# %% [markdown]
# Malaria is endemic in Nigeria and remains a major public health problem, taking its greatest toll on children under age 5 and pregnant women, although it is preventable, treatable, and curable. Africa still bears over 80 percent of the global malaria burden, and Nigeria accounts for about 29 percent of this burden. Moreover, in combination with the Democratic Republic of Congo, Nigeria contributes up to 40 percent of the global burden (World Malaria Report 2014). In Nigeria, malaria is responsible for approximately 60 percent of outpatient visits and 30 percent of admissions.

# %% [markdown]
# This notebook use the Nigeria Malaria Indicator Survey (NMIS) dataset to perform some descriptive analysis using python programming.

# %% [markdown]
# To use the dataset we will have to load in the dataset and perform some data cleaning.

# %% [markdown]
# Execute the code in the cell below to load the packages required for the rest of this notebook.

# %%
# perform necessary import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import numpy.random as nr
import math

# %matplotlib inline

# %% [markdown]
# Execute the code in the cell below to load the dataset and print the first few rows of the data frame.

# %%
# load datasets
Malaria = pd.read_csv('Nigeria Malaria Survey.csv')

# %%
Malaria.head(20)
# Out:
#     hhid       hv024  hv025                  hv201  \
# 0   1002  north west  urban         protected well
# 1   1004  north west  urban           tanker truck
# 2   1007  north west  urban  tube well or borehole
# 3   1010  north west  urban  tube well or borehole
# 4   1013  north west  urban           tanker truck
# 5   1016  north west  urban  tube well or borehole
# 6   1019  north west  urban  tube well or borehole
# 7   1022  north west  urban           tanker truck
# 8   1025  north west  urban           tanker truck
# 9   1027  north west  urban  tube well or borehole
# 10  1030  north west  urban           sachet water
# 11  1033  north west  urban   public tap/standpipe
# 12  1036  north west  urban  tube well or borehole
# 13  1039  north west  urban  tube well or borehole
# 14  1042  north west  urban           sachet water
# 15  1045  north west  urban           sachet water
# 16  1048  north west  urban           sachet water
# 17  1051  north west  urban   public tap/standpipe
# 18  1053  north west  urban  tube well or borehole
# 19  1056  north west  urban  tube well or borehole
#
#                                     hv205 hv206          hv213  \
# 0   ventilated improved pit latrine (vip)   yes         cement
# 1   ventilated improved pit latrine (vip)   yes   palm, bamboo
# 2   ventilated improved pit latrine (vip)   yes         cement
# 3   ventilated improved pit latrine (vip)   yes         cement
# 4   ventilated improved pit latrine (vip)   yes  ceramic tiles
# 5   ventilated improved pit latrine (vip)   yes    wood planks
# 6   ventilated improved pit latrine (vip)   yes         cement
# 7   ventilated improved pit latrine (vip)   yes         cement
# 8   ventilated improved pit latrine (vip)   yes         cement
# 9                   pit latrine with slab   yes         cement
# 10  ventilated improved pit latrine (vip)   yes         cement
# 11                  pit latrine with slab   yes         cement
# 12  ventilated improved pit latrine (vip)   yes         cement
# 13                  pit latrine with slab   yes         cement
# 14  ventilated improved pit latrine (vip)   yes         cement
# 15                   flush to pit latrine   yes         cement
# 16            flush to piped sewer system   yes  ceramic tiles
# 17  ventilated improved pit latrine (vip)   yes         cement
# 18  ventilated improved pit latrine (vip)   yes         cement
# 19  ventilated improved pit latrine (vip)   yes         cement
#
#              hv214       hv215 hv210 hv211 hv212 hv227 hv244 hv247    hv270  \
# 0           cement  zinc/metal    no    no    no   yes   yes    no   richer
# 1           cement  zinc/metal   yes    no   yes   yes   yes   yes   richer
# 2           cement  zinc/metal    no   yes    no   yes    no    no   richer
# 3           cement  zinc/metal   yes   yes   yes   yes    no    no  richest
# 4           cement  zinc/metal    no   yes   yes   yes    no   yes  richest
# 5        cardboard  zinc/metal    no   yes    no   yes   yes   yes   richer
# 6          plywood  zinc/metal    no    no   yes   yes    no   yes  richest
# 7           cement  zinc/metal    no   yes    no   yes    no   yes  richest
# 8           cement  zinc/metal    no   yes    no   yes    no   yes  richest
# 9           cement  zinc/metal    no    no    no    no    no    no   richer
# 10   cement blocks  zinc/metal    no    no    no    no    no    no   richer
# 11          cement  zinc/metal    no    no    no   yes   yes    no   richer
# 12   cement blocks  zinc/metal    no    no    no   yes    no    no   richer
# 13   cement blocks  zinc/metal    no    no    no   yes    no    no   richer
# 14   cement blocks  zinc/metal    no    no    no   yes    no    no   middle
# 15   cement blocks  zinc/metal   yes    no    no   yes    no   yes  richest
# 16          cement  zinc/metal    no   yes   yes   yes   yes   yes  richest
# 17  stone with mud  zinc/metal    no    no    no   yes    no   yes   middle
# 18          cement  zinc/metal   yes    no   yes   yes    no   yes  richest
# 19          cement  zinc/metal   yes    no    no   yes    no    no   richer
#
#     sh16_22 shstate
# 0       NaN  sokoto
# 1       NaN  sokoto
# 2       NaN  sokoto
# 3       NaN  sokoto
# 4       NaN  sokoto
# 5       NaN  sokoto
# 6       NaN  sokoto
# 7       NaN  sokoto
# 8       NaN  sokoto
# 9       NaN  sokoto
# 10      NaN  sokoto
# 11      NaN  sokoto
# 12      NaN  sokoto
# 13      NaN  sokoto
# 14      NaN  sokoto
# 15      NaN  sokoto
# 16      NaN  sokoto
# 17      NaN  sokoto
# 18      NaN  sokoto
# 19      NaN  sokoto

# %% [markdown]
# The column names in the dataset above have coded names. We are going to assign human-readable names to the columns and print shape and head of the data.

# %%
Malaria = pd.read_csv('Nigeria Malaria Survey.csv')
Malaria.columns=['Case Identification', 'Region', 'Type of Place of Residence', 'Source of Drinking Water', 'Type of Toilet Facility',
                'Has Electricity', 'Main Floor Material', 'Main Wall Material', 'Main Roof Material', 'Has Bicycle', 'Has Motorcycle/Scooter',
                'Has Car/Truck', 'Has Mosquito Bed Net for Sleeping', 'Owns Land Suitable for Agriculture', 'Has Bank Account', 
                'Wealth Index', 'Cost of Treatment for Fever', 'State']

print(Malaria.shape)
Malaria.head()
# Out:
# (7745, 18)
#    Case Identification      Region Type of Place of Residence  \
# 0                 1002  north west                      urban
# 1                 1004  north west                      urban
# 2                 1007  north west                      urban
# 3                 1010  north west                      urban
# 4                 1013  north west                      urban
#
#   Source of Drinking Water                Type of Toilet Facility  \
# 0           protected well  ventilated improved pit latrine (vip)
# 1             tanker truck  ventilated improved pit latrine (vip)
# 2    tube well or borehole  ventilated improved pit latrine (vip)
# 3    tube well or borehole  ventilated improved pit latrine (vip)
# 4             tanker truck  ventilated improved pit latrine (vip)
#
#   Has Electricity Main Floor Material Main Wall Material Main Roof Material  \
# 0             yes              cement             cement         zinc/metal
# 1             yes        palm, bamboo             cement         zinc/metal
# 2             yes              cement             cement         zinc/metal
# 3             yes              cement             cement         zinc/metal
# 4             yes       ceramic tiles             cement         zinc/metal
#
#   Has Bicycle Has Motorcycle/Scooter Has Car/Truck  \
# 0          no                     no            no
# 1         yes                     no           yes
# 2          no                    yes            no
# 3         yes                    yes           yes
# 4          no                    yes           yes
#
#   Has Mosquito Bed Net for Sleeping Owns Land Suitable for Agriculture  \
# 0                               yes                                yes
# 1                               yes                                yes
# 2                               yes                                 no
# 3                               yes                                 no
# 4                               yes                                 no
#
#   Has Bank Account Wealth Index  Cost of Treatment for Fever   State
# 0               no       richer                          NaN  sokoto
# 1              yes       richer                          NaN  sokoto
# 2               no       richer                          NaN  sokoto
# 3               no      richest                          NaN  sokoto
# 4              yes      richest                          NaN  sokoto

# %% [markdown]
# Recode names
# Notice that some of the column names contain the '/' character. Python will not correctly recognize character strings containing '-'. Rather, such a name will be recognized as two character strings. The same problem will occur with column values containing many special characters including, '-', ',', '*', '|', '>', '<', '@', '!' etc. If such characters appear in column names of values, they must be replaced with another character.
#
# Execute the code in the cell below to replace the '/' characters by 'or'.

# %%
Malaria.columns=[str.replace('/','or') for str in Malaria.columns]

# %% [markdown]
# Print the head of the data again to confirm changes have been made.

# %%
Malaria.head()
# Out:
#    Case Identification      Region Type of Place of Residence  \
# 0                 1002  north west                      urban
# 1                 1004  north west                      urban
# 2                 1007  north west                      urban
# 3                 1010  north west                      urban
# 4                 1013  north west                      urban
#
#   Source of Drinking Water                Type of Toilet Facility  \
# 0           protected well  ventilated improved pit latrine (vip)
# 1             tanker truck  ventilated improved pit latrine (vip)
# 2    tube well or borehole  ventilated improved pit latrine (vip)
# 3    tube well or borehole  ventilated improved pit latrine (vip)
# 4             tanker truck  ventilated improved pit latrine (vip)
#
#   Has Electricity Main Floor Material Main Wall Material Main Roof Material  \
# 0             yes              cement             cement         zinc/metal
# 1             yes        palm, bamboo             cement         zinc/metal
# 2             yes              cement             cement         zinc/metal
# 3             yes              cement             cement         zinc/metal
# 4             yes       ceramic tiles             cement         zinc/metal
#
#   Has Bicycle Has MotorcycleorScooter Has CarorTruck  \
# 0          no                      no             no
# 1         yes                      no            yes
# 2          no                     yes             no
# 3         yes                     yes            yes
# 4          no                     yes            yes
#
#   Has Mosquito Bed Net for Sleeping Owns Land Suitable for Agriculture  \
# 0                               yes                                yes
# 1                               yes                                yes
# 2                               yes                                 no
# 3                               yes                                 no
# 4                               yes                                 no
#
#   Has Bank Account Wealth Index  Cost of Treatment for Fever   State
# 0               no       richer                          NaN  sokoto
# 1              yes       richer                          NaN  sokoto
# 2               no       richer                          NaN  sokoto
# 3               no      richest                          NaN  sokoto
# 4              yes      richest                          NaN  sokoto

# %% [markdown]
# Execute the code in the cell below to display the data types of each column.

# %%
Malaria.dtypes
# Out:
# Case Identification                     int64
# Region                                 object
# Type of Place of Residence             object
# Source of Drinking Water               object
# Type of Toilet Facility                object
# Has Electricity                        object
# Main Floor Material                    object
# Main Wall Material                     object
# Main Roof Material                     object
# Has Bicycle                            object
# Has MotorcycleorScooter                object
# Has CarorTruck                         object
# Has Mosquito Bed Net for Sleeping      object
# Owns Land Suitable for Agriculture     object
# Has Bank Account                       object
# Wealth Index                           object
# Cost of Treatment for Fever           float64
# State                                  object
# dtype: object

# %% [markdown]
# # Treat missing values
# Missing values are a common problem in data set. Failure to deal with missing values before training a machine learning model will lead to biased training at best, and in many cases actual failure. The Python scikit-learn package will not process arrays with missing values.

# %% [markdown]
# We are going to check which of our columns have missing value(s)

# %%
# check for missing values
(Malaria.astype(np.object).isnull()).any()
# Out:
# Case Identification                   False
# Region                                False
# Type of Place of Residence            False
# Source of Drinking Water              False
# Type of Toilet Facility                True
# Has Electricity                       False
# Main Floor Material                   False
# Main Wall Material                    False
# Main Roof Material                    False
# Has Bicycle                           False
# Has MotorcycleorScooter               False
# Has CarorTruck                        False
# Has Mosquito Bed Net for Sleeping     False
# Owns Land Suitable for Agriculture    False
# Has Bank Account                      False
# Wealth Index                          False
# Cost of Treatment for Fever            True
# State                                 False
# dtype: bool

# %% [markdown]
#  'Type of Toilet Facility' and 'Cost of Treatment for Fever' contains missing values. We are going to remove both columns from our dataset.

# %%
Malaria.drop('Type of Toilet Facility', axis=1, inplace=True)

# %%
Malaria.drop('Cost of Treatment for Fever', axis=1, inplace=True)

# %% [markdown]
# Examine to see if both columns have been removed

# %%
Malaria.head()
# Out:
#    Case Identification      Region Type of Place of Residence  \
# 0                 1002  north west                      urban
# 1                 1004  north west                      urban
# 2                 1007  north west                      urban
# 3                 1010  north west                      urban
# 4                 1013  north west                      urban
#
#   Source of Drinking Water Has Electricity Main Floor Material  \
# 0           protected well             yes              cement
# 1             tanker truck             yes        palm, bamboo
# 2    tube well or borehole             yes              cement
# 3    tube well or borehole             yes              cement
# 4             tanker truck             yes       ceramic tiles
#
#   Main Wall Material Main Roof Material Has Bicycle Has MotorcycleorScooter  \
# 0             cement         zinc/metal          no                      no
# 1             cement         zinc/metal         yes                      no
# 2             cement         zinc/metal          no                     yes
# 3             cement         zinc/metal         yes                     yes
# 4             cement         zinc/metal          no                     yes
#
#   Has CarorTruck Has Mosquito Bed Net for Sleeping  \
# 0             no                               yes
# 1            yes                               yes
# 2             no                               yes
# 3            yes                               yes
# 4            yes                               yes
#
#   Owns Land Suitable for Agriculture Has Bank Account Wealth Index   State
# 0                                yes               no       richer  sokoto
# 1                                yes              yes       richer  sokoto
# 2                                 no               no       richer  sokoto
# 3                                 no               no      richest  sokoto
# 4                                 no              yes      richest  sokoto

# %% [markdown]
# # Transform column data type

# %% [markdown]
# We have now eliminated all missing values from our dataset. For descriptive analysis purpose.First is to put our table in form of Pandas DataFrame.

# %%
df = pd.DataFrame(Malaria)

# %%
df
# Out:
#       Case Identification      Region Type of Place of Residence  \
# 0                    1002  north west                      urban
# 1                    1004  north west                      urban
# 2                    1007  north west                      urban
# 3                    1010  north west                      urban
# 4                    1013  north west                      urban
# 5                    1016  north west                      urban
# 6                    1019  north west                      urban
# 7                    1022  north west                      urban
# 8                    1025  north west                      urban
# 9                    1027  north west                      urban
# 10                   1030  north west                      urban
# 11                   1033  north west                      urban
# 12                   1036  north west                      urban
# 13                   1039  north west                      urban
# 14                   1042  north west                      urban
# 15                   1045  north west                      urban
# 16                   1048  north west                      urban
# 17                   1051  north west                      urban
# 18                   1053  north west                      urban
# 19                   1056  north west                      urban
# 20                   1059  north west                      urban
# 21                   1062  north west                      urban
# 22                   1065  north west                      urban
# 23                   1068  north west                      urban
# 24                   1071  north west                      urban
# 25                   2003  north west                      urban
# 26                   2005  north west                      urban
# 27                   2007  north west                      urban
# 28                   2009  north west                      urban
# 29                   2011  north west                      urban
# ...                   ...         ...                        ...
# 7715               332027  south west                      rural
# 7716               332029  south west                      rural
# 7717               332030  south west                      rural
# 7718               332031  south west                      rural
# 7719               332032  south west                      rural
# 7720               333005  south west                      rural
# 7721               333010  south west                      rural
# 7722               333015  south west                      rural
# 7723               333020  south west                      rural
# 7724               333026  south west                      rural
# 7725               333031  south west                      rural
# 7726               333036  south west                      rural
# 7727               333041  south west                      rural
# 7728               333046  south west                      rural
# 7729               333051  south west                      rural
# 7730               333057  south west                      rural
# 7731               333062  south west                      rural
# 7732               333067  south west                      rural
# 7733               333072  south west                      rural
# 7734               333077  south west                      rural
# 7735               333082  south west                      rural
# 7736               333088  south west                      rural
# 7737               333093  south west                      rural
# 7738               333098  south west                      rural
# 7739               333103  south west                      rural
# 7740               333108  south west                      rural
# 7741               333113  south west                      rural
# 7742               333119  south west                      rural
# 7743               333124  south west                      rural
# 7744               333129  south west                      rural
#
#      Source of Drinking Water Has Electricity Main Floor Material  \
# 0              protected well             yes              cement
# 1                tanker truck             yes        palm, bamboo
# 2       tube well or borehole             yes              cement
# 3       tube well or borehole             yes              cement
# 4                tanker truck             yes       ceramic tiles
# 5       tube well or borehole             yes         wood planks
# 6       tube well or borehole             yes              cement
# 7                tanker truck             yes              cement
# 8                tanker truck             yes              cement
# 9       tube well or borehole             yes              cement
# 10               sachet water             yes              cement
# 11       public tap/standpipe             yes              cement
# 12      tube well or borehole             yes              cement
# 13      tube well or borehole             yes              cement
# 14               sachet water             yes              cement
# 15               sachet water             yes              cement
# 16               sachet water             yes       ceramic tiles
# 17       public tap/standpipe             yes              cement
# 18      tube well or borehole             yes              cement
# 19      tube well or borehole             yes              cement
# 20      tube well or borehole             yes       ceramic tiles
# 21       public tap/standpipe             yes              cement
# 22      tube well or borehole             yes              cement
# 23      tube well or borehole             yes              cement
# 24       public tap/standpipe             yes              cement
# 25       public tap/standpipe             yes         wood planks
# 26      tube well or borehole             yes         wood planks
# 27       public tap/standpipe             yes         wood planks
# 28      tube well or borehole             yes              cement
# 29      tube well or borehole             yes              cement
# ...                       ...             ...                 ...
# 7715    tube well or borehole             yes              cement
# 7716    tube well or borehole             yes              cement
# 7717    tube well or borehole             yes              cement
# 7718    tube well or borehole             yes              cement
# 7719    tube well or borehole             yes              cement
# 7720             sachet water              no         earth, sand
# 7721             sachet water             yes              cement
# 7722             sachet water             yes              cement
# 7723             sachet water             yes              carpet
# 7724           protected well             yes              cement
# 7725             sachet water             yes              cement
# 7726             sachet water             yes              cement
# 7727             sachet water             yes              cement
# 7728             sachet water             yes              cement
# 7729            bottled water             yes       ceramic tiles
# 7730    tube well or borehole              no              cement
# 7731             sachet water             yes       ceramic tiles
# 7732             sachet water             yes              cement
# 7733             sachet water             yes              cement
# 7734    tube well or borehole             yes              cement
# 7735             sachet water             yes              cement
# 7736             sachet water             yes              cement
# 7737    tube well or borehole             yes              cement
# 7738    tube well or borehole             yes              cement
# 7739             sachet water             yes              cement
# 7740    tube well or borehole             yes              cement
# 7741             sachet water             yes              cement
# 7742             sachet water             yes       ceramic tiles
# 7743    tube well or borehole             yes              cement
# 7744             sachet water             yes              carpet
#
#           Main Wall Material Main Roof Material Has Bicycle  \
# 0                     cement         zinc/metal          no
# 1                     cement         zinc/metal         yes
# 2                     cement         zinc/metal          no
# 3                     cement         zinc/metal         yes
# 4                     cement         zinc/metal          no
# 5                  cardboard         zinc/metal          no
# 6                    plywood         zinc/metal          no
# 7                     cement         zinc/metal          no
# 8                     cement         zinc/metal          no
# 9                     cement         zinc/metal          no
# 10             cement blocks         zinc/metal          no
# 11                    cement         zinc/metal          no
# 12             cement blocks         zinc/metal          no
# 13             cement blocks         zinc/metal          no
# 14             cement blocks         zinc/metal          no
# 15             cement blocks         zinc/metal         yes
# 16                    cement         zinc/metal          no
# 17            stone with mud         zinc/metal          no
# 18                    cement         zinc/metal         yes
# 19                    cement         zinc/metal         yes
# 20                    cement         zinc/metal          no
# 21             cement blocks         zinc/metal          no
# 22    stone with lime/cement         zinc/metal          no
# 23             cement blocks         zinc/metal          no
# 24             cement blocks         zinc/metal          no
# 25                    cement         zinc/metal          no
# 26                    cement         zinc/metal          no
# 27                      dirt         zinc/metal         yes
# 28                    cement         zinc/metal          no
# 29                    cement         zinc/metal          no
# ...                      ...                ...         ...
# 7715                  cement   roofing shingles          no
# 7716                  cement         zinc/metal          no
# 7717                  cement         zinc/metal          no
# 7718                  cement         zinc/metal          no
# 7719                  cement   roofing shingles          no
# 7720                  cement      ceramic tiles          no
# 7721                  cement   roofing shingles          no
# 7722                  cement         zinc/metal          no
# 7723                  cement         zinc/metal          no
# 7724                  cement   roofing shingles          no
# 7725                  cement   roofing shingles          no
# 7726                  cement         zinc/metal          no
# 7727                  cement              other          no
# 7728                  cement         zinc/metal          no
# 7729                  cement         zinc/metal         yes
# 7730                  cement         zinc/metal          no
# 7731  stone with lime/cement         zinc/metal          no
# 7732                  cement   roofing shingles          no
# 7733                  cement   roofing shingles          no
# 7734                  cement   roofing shingles          no
# 7735                  cement   roofing shingles          no
# 7736                  cement   roofing shingles          no
# 7737                  cement         zinc/metal          no
# 7738                  cement         zinc/metal          no
# 7739                  cement         zinc/metal          no
# 7740                  cement   roofing shingles          no
# 7741                  cement   roofing shingles          no
# 7742                  cement   roofing shingles          no
# 7743                  cement   roofing shingles          no
# 7744                  cement   roofing shingles          no
#
#      Has MotorcycleorScooter Has CarorTruck Has Mosquito Bed Net for Sleeping  \
# 0                         no             no                               yes
# 1                         no            yes                               yes
# 2                        yes             no                               yes
# 3                        yes            yes                               yes
# 4                        yes            yes                               yes
# 5                        yes             no                               yes
# 6                         no            yes                               yes
# 7                        yes             no                               yes
# 8                        yes             no                               yes
# 9                         no             no                                no
# 10                        no             no                                no
# 11                        no             no                               yes
# 12                        no             no                               yes
# 13                        no             no                               yes
# 14                        no             no                               yes
# 15                        no             no                               yes
# 16                       yes            yes                               yes
# 17                        no             no                               yes
# 18                        no            yes                               yes
# 19                        no             no                               yes
# 20                        no            yes                               yes
# 21                        no             no                                no
# 22                        no            yes                               yes
# 23                       yes             no                               yes
# 24                        no             no                               yes
# 25                       yes             no                               yes
# 26                       yes             no                               yes
# 27                        no             no                               yes
# 28                        no             no                               yes
# 29                        no             no                               yes
# ...                      ...            ...                               ...
# 7715                      no             no                               yes
# 7716                      no             no                                no
# 7717                     yes             no                               yes
# 7718                      no             no                                no
# 7719                      no            yes                                no
# 7720                      no             no                                no
# 7721                     yes            yes                                no
# 7722                      no            yes                               yes
# 7723                      no            yes                                no
# 7724                      no             no                                no
# 7725                      no             no                               yes
# 7726                      no            yes                               yes
# 7727                      no            yes                                no
# 7728                     yes             no                               yes
# 7729                      no            yes                               yes
# 7730                      no             no                               yes
# 7731                      no             no                                no
# 7732                      no             no                                no
# 7733                      no             no                                no
# 7734                      no             no                                no
# 7735                      no            yes                               yes
# 7736                      no             no                               yes
# 7737                      no             no                               yes
# 7738                     yes             no                               yes
# 7739                     yes             no                               yes
# 7740                      no             no                               yes
# 7741                      no             no                               yes
# 7742                      no             no                                no
# 7743                     yes             no                               yes
# 7744                      no            yes                               yes
#
#      Owns Land Suitable for Agriculture Has Bank Account Wealth Index   State
# 0                                   yes               no       richer  sokoto
# 1                                   yes              yes       richer  sokoto
# 2                                    no               no       richer  sokoto
# 3                                    no               no      richest  sokoto
# 4                                    no              yes      richest  sokoto
# 5                                   yes              yes       richer  sokoto
# 6                                    no              yes      richest  sokoto
# 7                                    no              yes      richest  sokoto
# 8                                    no              yes      richest  sokoto
# 9                                    no               no       richer  sokoto
# 10                                   no               no       richer  sokoto
# 11                                  yes               no       richer  sokoto
# 12                                   no               no       richer  sokoto
# 13                                   no               no       richer  sokoto
# 14                                   no               no       middle  sokoto
# 15                                   no              yes      richest  sokoto
# 16                                  yes              yes      richest  sokoto
# 17                                   no              yes       middle  sokoto
# 18                                   no              yes      richest  sokoto
# 19                                   no               no       richer  sokoto
# 20                                   no              yes      richest  sokoto
# 21                                   no               no      richest  sokoto
# 22                                  yes               no      richest  sokoto
# 23                                   no               no       richer  sokoto
# 24                                   no              yes      richest  sokoto
# 25                                   no               no       richer  sokoto
# 26                                   no              yes       richer  sokoto
# 27                                  yes              yes       middle  sokoto
# 28                                   no              yes       richer  sokoto
# 29                                   no              yes       richer  sokoto
# ...                                 ...              ...          ...     ...
# 7715                                 no               no       richer    ogun
# 7716                                yes               no       richer    ogun
# 7717                                yes               no       richer    ogun
# 7718                                 no              yes       richer    ogun
# 7719                                 no              yes       richer    ogun
# 7720                                 no               no       richer    ogun
# 7721                                 no              yes      richest    ogun
# 7722                                 no              yes      richest    ogun
# 7723                                 no              yes      richest    ogun
# 7724                                 no               no       richer    ogun
# 7725                                 no              yes      richest    ogun
# 7726                                 no              yes      richest    ogun
# 7727                                 no               no       richer    ogun
# 7728                                 no              yes      richest    ogun
# 7729                                 no              yes      richest    ogun
# 7730                                 no              yes       richer    ogun
# 7731                                 no              yes      richest    ogun
# 7732                                 no              yes       richer    ogun
# 7733                                yes              yes      richest    ogun
# 7734                                 no              yes       richer    ogun
# 7735                                 no              yes       richer    ogun
# 7736                                 no              yes      richest    ogun
# 7737                                 no              yes       richer    ogun
# 7738                                 no              yes      richest    ogun
# 7739                                 no              yes      richest    ogun
# 7740                                 no              yes      richest    ogun
# 7741                                 no              yes      richest    ogun
# 7742                                 no              yes      richest    ogun
# 7743                                yes              yes      richest    ogun
# 7744                                 no              yes      richest    ogun
#
# [7745 rows x 16 columns]

# %% [markdown]
# # Descriptive Statistics

# %%
df['State'].value_counts()
# Out:
# yobe             225
# adamawa          225
# lagos            225
# taraba           225
# gombe            225
# bayelsa          225
# bauchi           225
# abia             225
# cross river      225
# jigawa           225
# sokoto           224
# oyo              224
# ondo             223
# kebbi            223
# osun             221
# katsina          220
# akwa ibom        220
# rivers           220
# ogun             220
# zamfara          220
# kaduna           219
# enugu            217
# ekiti            217
# kano             216
# benue            211
# edo              211
# kogi             211
# niger            206
# ebonyi           201
# nasarawa         200
# plateau          196
# kwara            194
# imo              191
# delta            180
# anambra          168
# fct abuja        167
# borno - urban     75
# Name: State, dtype: int64

# %%
df['Has Electricity'].value_counts()
# Out:
# yes    4247
# no     3498
# Name: Has Electricity, dtype: int64

# %%
df['Source of Drinking Water'].value_counts()
# Out:
# tube well or borehole                                   2795
# river/dam/lake/ponds/stream/canal/irrigation channel     829
# unprotected well                                         819
# protected well                                           786
# sachet water                                             786
# public tap/standpipe                                     393
# unprotected spring                                       349
# rainwater                                                308
# piped into dwelling                                      238
# piped to yard/plot                                       101
# protected spring                                          87
# piped to neighbor                                         84
# tanker truck                                              71
# bottled water                                             68
# cart with small tank                                      27
# other                                                      4
# Name: Source of Drinking Water, dtype: int64

# %%
df['Wealth Index'].value_counts()
# Out:
# richer     1844
# richest    1816
# middle     1676
# poorer     1351
# poorest    1058
# Name: Wealth Index, dtype: int64

# %%
df['Has Mosquito Bed Net for Sleeping'].value_counts()
# Out:
# yes    5432
# no     2313
# Name: Has Mosquito Bed Net for Sleeping, dtype: int64

# %%
df.groupby('Wealth Index')['State'].describe()
# Out:
#              count unique       top freq
# Wealth Index
# middle        1676     37  nasarawa   89
# poorer        1351     35    taraba   97
# poorest       1058     25    sokoto  108
# richer        1844     37     ekiti  107
# richest       1816     36     lagos  207

# %% [markdown]
# From the table above, Lagos State has the top number of richest people and Sokoto State has the top number of poorest people.

# %%
df.groupby('Has Mosquito Bed Net for Sleeping')['State'].describe()
# Out:
#                                   count unique     top freq
# Has Mosquito Bed Net for Sleeping
# no                                 2313     37     edo  124
# yes                                5432     37  bauchi  221

# %% [markdown]
# From above table Bauchi State has the Highest number of people with Mosquito Bed Net for Sleeping, While Edo State has the least Number.

# %%
df.groupby('Has Electricity')['State'].describe()
# Out:
#                 count unique      top freq
# Has Electricity
# no               3498     37  adamawa  189
# yes              4247     37    lagos  224

# %% [markdown]
# From above table Lagos State has the Highest number of people with access to Electricity, While Adamawa State has the least Number.

# %%
df['Source of Drinking Water'].value_counts()
# Out:
# tube well or borehole                                   2795
# river/dam/lake/ponds/stream/canal/irrigation channel     829
# unprotected well                                         819
# protected well                                           786
# sachet water                                             786
# public tap/standpipe                                     393
# unprotected spring                                       349
# rainwater                                                308
# piped into dwelling                                      238
# piped to yard/plot                                       101
# protected spring                                          87
# piped to neighbor                                         84
# tanker truck                                              71
# bottled water                                             68
# cart with small tank                                      27
# other                                                      4
# Name: Source of Drinking Water, dtype: int64

# %% [markdown]
# From the table above, most people source of drinking water is Tube Well or Borehole.
